# %%
import pandas as pd

# %%
datas = pd.read_csv(r"C:\Users\munir\Documents\sex4grades\Sex4Grades\Data\updated\Old data set\sex4grades.csv")
datas_2 = datas.set_index('username', drop = False)
datas_2[["name","location"]]
# Out:
#                                                name  \
# username
# @paulo51101948                                paulo
# @paulo51101948                                paulo
# @okonud                                    Udy Okon
# @YAFng                       Youth Alive Foundation
# @I_williamsdavid                            The One
# @I_williamsdavid                            The One
# @Jire_                                            J
# @NaijaGoBeta1     Fatima Adu (Affidavit First Lady)
# @S_U_Dikko                            💦 💥D.Legacy 👑
# @DonKushkings                        Prof Kushkings
# @kalempire               REVOLUTIONARY HOUSE OF KAL
# @resourceme                                oke epia
# @foxnaija247                              FOX Naija
# @YAFng                       Youth Alive Foundation
# @YAFng                       Youth Alive Foundation
# @YAFng                       Youth Alive Foundation
# @i_amivysan                                👑Xt 🌟r 💎
# ...

# %%
datas
# Out:
#                                   name          username  \
# 0                                paulo    @paulo51101948
# 1                                paulo    @paulo51101948
# 2                             Udy Okon           @okonud
# 3               Youth Alive Foundation            @YAFng
# 4                              The One  @I_williamsdavid
# 5                              The One  @I_williamsdavid
# 6                                    J            @Jire_
# 7    Fatima Adu (Affidavit First Lady)     @NaijaGoBeta1
# 8                        💦 💥D.Legacy 👑        @S_U_Dikko
# 9                       Prof Kushkings     @DonKushkings
# 10          REVOLUTIONARY HOUSE OF KAL        @kalempire
# 11                            oke epia       @resourceme
# 12                           FOX Naija      @foxnaija247
# 13              Youth Alive Foundation            @YAFng
# 14              Youth Alive Foundation            @YAFng
# ...
